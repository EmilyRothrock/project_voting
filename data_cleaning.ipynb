# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyRothrock/project_voting/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! git clone 'https://github.com/EmilyRothrock/project_voting'

# %% [markdown]
# #Resources
# https://stackoverflow.com/questions/75956209/error-dataframe-object-has-no-attribute-append
# https://flexiple.com/python/python-uppercase
# https://medium.com/@geencay/predicting-president-election-by-bootstrapping-in-python-a1bd8fa122cc
# https://www.geeksforgeeks.org/random-forest-regression-in-python/
# https://towardsdatascience.com/how-i-predicted-the-election-result-with-simple-linear-regression-e54c6c196239
# https://github.com/CezaryKlimczuk/PresidentialElection2020/blob/master/Election%20Analysis.ipynb
# https://colab.research.google.com/drive/1Z1aiXravQxrUKJbk1ciTy0DZ_yhBopZS?usp=sharing
# https://colab.research.google.com/drive/1Z1aiXravQxrUKJbk1ciTy0DZ_yhBopZS?usp=sharing
# https://medium.com/@lfoster49203/predicting-election-outcomes-with-machine-learning-a-tutorial-in-python-4c309904e0e1
# https://libguides.princeton.edu/elections
# https://medium.com/@roiyeho/random-forests-98892261dc49
# https://medium.com/@mrmaster907/introduction-random-forest-classification-by-example-6983d95c7b91
# https://stackoverflow.com/questions/24109779/running-get-dummies-on-several-dataframe-columns
# https://medium.com/analytics-vidhya/evaluating-a-random-forest-model-9d165595ad56
# https://towardsdatascience.com/random-forest-ca80e56224c1
# https://electionlab.mit.edu/data
# https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/VOQCHQ
# https://saturncloud.io/blog/how-to-remove-decimal-points-in-pandas-a-guide-for-data-scientists/#:~:text=Method%201%3A%20Using%20the%20round()%20Function,-The%20simplest%20way&text=As%20you%20can%20see%2C%20the,col1'%20column%20of%20the%20dataframe.
# https://www.aporia.com/resources/how-to/select-rows-in-dataframe-from-list/#:~:text=and%20PySpark%20DataFrames.-,Pandas,conditions%20inside%20a%20Python%20list.&text=If%20you%20are%20interested%20in,set%20the%20condition%20as%20False.
# https://pandas.pydata.org/docs/user_guide/merging.html

# %% [markdown]
# # Data
# https://www.census.gov/programs-surveys/popest/technical-documentation/research/evaluation-estimates/2020-evaluation-estimates/2010s-counties-total.html
#
#
# https://www.census.gov/data/datasets/time-series/demo/popest/intercensal-2000-2010-counties.html

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## Virginia Voting Data

# %%
# Import libraries
import pandas as pd
vdf = pd.read_csv('./project_voting/data/voting_VA.csv') # Load historical voting data
vdf = vdf.drop(columns=['Unnamed: 0', 'state_po'])
vdf
# Out:
#       year     state      county_name  county_fips        office  \
# 0     2000  VIRGINIA         ACCOMACK        51001  US PRESIDENT
# 1     2000  VIRGINIA         ACCOMACK        51001  US PRESIDENT
# 2     2000  VIRGINIA         ACCOMACK        51001  US PRESIDENT
# 3     2000  VIRGINIA         ACCOMACK        51001  US PRESIDENT
# 4     2000  VIRGINIA        ALBEMARLE        51003  US PRESIDENT
# ...    ...       ...              ...          ...           ...
# 3731  2020  VIRGINIA  WINCHESTER CITY        51840  US PRESIDENT
# 3732  2020  VIRGINIA  WINCHESTER CITY        51840  US PRESIDENT
# 3733  2020  VIRGINIA  WINCHESTER CITY        51840  US PRESIDENT
# 3734  2020  VIRGINIA  WINCHESTER CITY        51840  US PRESIDENT
# 3735  2020  VIRGINIA  WINCHESTER CITY        51840  US PRESIDENT
#
#            candidate       party  candidatevotes  totalvotes   version  \
# 0            AL GORE    DEMOCRAT            5092       11925  20220315
# 1     GEORGE W. BUSH  REPUBLICAN            6352       11925  20220315
# 2        RALPH NADER       GREEN             220       11925  20220315
# 3              OTHER       OTHER             261       11925  20220315
# 4            AL GORE    DEMOCRAT           16255       36846  20220315
# ...              ...         ...             ...         ...       ...
# 3731           OTHER       OTHER              24       12113  20220315
# 3732           OTHER       OTHER               0       12113  20220315
# 3733  DONALD J TRUMP  REPUBLICAN            2825       12113  20220315
# 3734  DONALD J TRUMP  REPUBLICAN            2370       12113  20220315
# 3735  DONALD J TRUMP  REPUBLICAN              26       12113  20220315
#
#               mode
# 0            TOTAL
# 1            TOTAL
# 2            TOTAL
# 3            TOTAL
# 4            TOTAL
# ...            ...
# 3731  ELECTION DAY
# 3732   PROVISIONAL
# 3733      ABSENTEE
# 3734  ELECTION DAY
# 3735   PROVISIONAL
#
# [3736 rows x 11 columns]

# %%
print(vdf['mode'].unique())
print(vdf.loc[vdf['mode'] == 'ELECTION DAY']['year'].unique())
print(vdf.loc[vdf['mode'] == 'TOTAL']['year'].unique())
# Out:
# ['TOTAL' 'ABSENTEE' 'ELECTION DAY' 'PROVISIONAL']
# [2020]
# [2000 2004 2008 2012 2016]

# %% [markdown]
# The output aboves shows that previous years only give the total number of votes per candidate, and only in 2020 is the data split up into other categories and has no total.

# %%
print(vdf['office'].unique())
vdf = vdf.drop(columns=['office'])
# Out:
# ['US PRESIDENT']

# %% [markdown]
# We don't need the 'office' column since every value is the same.

# %%
vdf
# Out:
#       year     state      county_name  county_fips       candidate  \
# 0     2000  VIRGINIA         ACCOMACK        51001         AL GORE
# 1     2000  VIRGINIA         ACCOMACK        51001  GEORGE W. BUSH
# 2     2000  VIRGINIA         ACCOMACK        51001     RALPH NADER
# 3     2000  VIRGINIA         ACCOMACK        51001           OTHER
# 4     2000  VIRGINIA        ALBEMARLE        51003         AL GORE
# ...    ...       ...              ...          ...             ...
# 3731  2020  VIRGINIA  WINCHESTER CITY        51840           OTHER
# 3732  2020  VIRGINIA  WINCHESTER CITY        51840           OTHER
# 3733  2020  VIRGINIA  WINCHESTER CITY        51840  DONALD J TRUMP
# 3734  2020  VIRGINIA  WINCHESTER CITY        51840  DONALD J TRUMP
# 3735  2020  VIRGINIA  WINCHESTER CITY        51840  DONALD J TRUMP
#
#            party  candidatevotes  totalvotes   version          mode
# 0       DEMOCRAT            5092       11925  20220315         TOTAL
# 1     REPUBLICAN            6352       11925  20220315         TOTAL
# 2          GREEN             220       11925  20220315         TOTAL
# 3          OTHER             261       11925  20220315         TOTAL
# 4       DEMOCRAT           16255       36846  20220315         TOTAL
# ...          ...             ...         ...       ...           ...
# 3731       OTHER              24       12113  20220315  ELECTION DAY
# 3732       OTHER               0       12113  20220315   PROVISIONAL
# 3733  REPUBLICAN            2825       12113  20220315      ABSENTEE
# 3734  REPUBLICAN            2370       12113  20220315  ELECTION DAY
# 3735  REPUBLICAN              26       12113  20220315   PROVISIONAL
#
# [3736 rows x 10 columns]

# %%
# select only 2020 voting history
vdf_2020 = vdf.loc[vdf['year'] == 2020]
vdf_2020 = vdf_2020.dropna()
vdf_2020
# Out:
#       year     state      county_name  county_fips          candidate  \
# 2144  2020  VIRGINIA         ACCOMACK        51001  JOSEPH R BIDEN JR
# 2145  2020  VIRGINIA         ACCOMACK        51001  JOSEPH R BIDEN JR
# 2146  2020  VIRGINIA         ACCOMACK        51001  JOSEPH R BIDEN JR
# 2147  2020  VIRGINIA         ACCOMACK        51001       JO JORGENSEN
# 2148  2020  VIRGINIA         ACCOMACK        51001       JO JORGENSEN
# ...    ...       ...              ...          ...                ...
# 3731  2020  VIRGINIA  WINCHESTER CITY        51840              OTHER
# 3732  2020  VIRGINIA  WINCHESTER CITY        51840              OTHER
# 3733  2020  VIRGINIA  WINCHESTER CITY        51840     DONALD J TRUMP
# 3734  2020  VIRGINIA  WINCHESTER CITY        51840     DONALD J TRUMP
# 3735  2020  VIRGINIA  WINCHESTER CITY        51840     DONALD J TRUMP
#
#             party  candidatevotes  totalvotes   version          mode
# 2144     DEMOCRAT            5495       16962  20220315      ABSENTEE
# 2145     DEMOCRAT            2072       16962  20220315  ELECTION DAY
# 2146     DEMOCRAT              11       16962  20220315   PROVISIONAL
# 2147  LIBERTARIAN              66       16962  20220315      ABSENTEE
# 2148  LIBERTARIAN             122       16962  20220315  ELECTION DAY
# ...           ...             ...         ...       ...           ...
# 3731        OTHER              24       12113  20220315  ELECTION DAY
# 3732        OTHER               0       12113  20220315   PROVISIONAL
# 3733   REPUBLICAN            2825       12113  20220315      ABSENTEE
# 3734   REPUBLICAN            2370       12113  20220315  ELECTION DAY
# 3735   REPUBLICAN              26       12113  20220315   PROVISIONAL
#
# [1592 rows x 10 columns]

# %%
cdf = pd.read_csv('./project_voting/data/county_adjacencies.csv') # Load county adjacency data and population data
cdf.loc[:, 'County'].str.upper().replace(" ", "")
cdf
# Out:
#                County  Population2022   FIPS  District                   N1  \
# 0            Accomack           33191  51001         2       Northumberland
# 1           Albemarle          114534  51003         5  CharlottesvilleCity
# 2      AlexandriaCity          155525  51510         8              Fairfax
# 3           Alleghany           14835  51005         6                Craig
# 4              Amelia           13455  51007         5         PrinceEdward
# ..                ...             ...    ...       ...                  ...
# 128    WinchesterCity           27936  51840         6            Frederick
# 129              Wise           35421  51195         9                  Lee
# 130             Wythe           28111  51197         9                Bland
# 131              York           71341  51199         1           Gloucester
# 132  WilliamsburgCity           15920  51830         1             JamesCty
#
#              N2                N3               N4            N5           N6  \
# 0     Lancaster         Middlesex          Mathews   Northampton          NaN
# 1        Nelson           Augusta       Rockingham        Greene       Orange
# 2     Arlington               NaN              NaN           NaN          NaN
# 3          Bath         Botetourt    CovingtonCity    Rockbridge          NaN
# 4    Cumberland          Powhatan     Chesterfield     Dinwiddie     Nottoway
# ..          ...               ...              ...           ...          ...
# 128         NaN               NaN              NaN           NaN          NaN
# 129       Scott         Dickenson       NortonCity       Russell          NaN
# 130       Smyth           Grayson          Carroll       Pulaski          NaN
# 131    JamesCty  WilliamsburgCity  NewportNewsCity  PoquosonCity  HamptonCity
# 132        York               NaN              NaN           NaN          NaN
#
#               N7        N8          N9     N10  N11  N12
# 0            NaN       NaN         NaN     NaN  NaN  NaN
# 1         Louisa  Fluvanna  Buckingham  Nelson  NaN  NaN
# 2            NaN       NaN         NaN     NaN  NaN  NaN
# 3            NaN       NaN         NaN     NaN  NaN  NaN
# 4            NaN       NaN         NaN     NaN  NaN  NaN
# ..           ...       ...         ...     ...  ...  ...
# 128          NaN       NaN         NaN     NaN  NaN  NaN
# 129          NaN       NaN         NaN     NaN  NaN  NaN
# 130          NaN       NaN         NaN     NaN  NaN  NaN
# 131  Northampton       NaN         NaN     NaN  NaN  NaN
# 132          NaN       NaN         NaN     NaN  NaN  NaN
#
# [133 rows x 16 columns]

# %% [markdown]
# The below two code blocks define two functions, calculate_votes and reorganize_dataframe. The calculate_votes function sums the number of votes across a given county for a given party. The reorganize_dataframe function utilizes the calculate_votes function to create a new dataframe with the number of democratic and republican votes, along with onther info, for each county. The columns of this dataframe are year, state, population, county, county_fips, democrat_votes, republican_votes, and total_votes.

# %%
def calculate_votes(df, county_col, party_col, votes_col, county_name, party):
    county = df.loc[df[county_col] == county_name]
    # print(county)
    votes = sum(county.loc[county[party_col] == party, votes_col])
    return votes

# %%
def reorganize_dataframe(df, cdf):
    county_names = df['county_name'].unique()
    new_df = pd.DataFrame(columns=['year', 'state', 'population', 'county', 'county_fips', 'democrat_votes', 'republican_votes', 'total_votes'])
    #print(county_names)
    for county in county_names:
        #print(df.loc[df['county_name'] == county])
        # df_county = df.loc[df['county_name'] == county]
        dem_votes = calculate_votes(df, 'county_name', 'party', 'candidatevotes', county, 'DEMOCRAT')
        rep_votes = calculate_votes(df, 'county_name', 'party', 'candidatevotes', county, 'REPUBLICAN')
        state = df.loc[df['county_name'] == county, 'state'].unique()[0]
        county_fips = df.loc[df['county_name'] == county, 'county_fips'].unique()[0]
        total_votes = df.loc[df['county_name'] == county, 'totalvotes'].unique()[0]
        county_population = sum(cdf.loc[cdf['County'].str.upper() == county.replace(" ", ""), 'Population2022'])

        new_row = {'year': 2020, 'state': state, 'population': county_population, 'county': county, 'county_fips': county_fips, 'democrat_votes': dem_votes, 'republican_votes': rep_votes, 'total_votes': total_votes}
        # Append the dictionary to the DataFrame
        #df.loc[len(df.index)] = [2020, state, county_population, county, county_fips, dem_votes, rep_votes, total_votes]
        new_df = pd.concat([new_df, pd.DataFrame([new_row])], ignore_index=True)
        # Reset the index
        # df = df.reset_index(drop=True)
        #print(f'COUNTY: {county}')
        #print(f'DEMOCRAT: {dem_votes}')
        #print(f'REPUBLICAN: {rep_votes}')
        #print(f'POPULATION: {county_population}')
        #print(f'STATE: {state}')
        #print(f'FIPS: {county_fips}')
        #print(f'TOTAL VOTES: {total_votes}\n')
    #print(new_df)
    return new_df

# %%
va_data_2020 = reorganize_dataframe(vdf_2020, cdf) # NOTE POPULATION DATA IS ACTUALLY FROM 2022
va_data_2020
# Out:
#      year     state population               county county_fips  \
# 0    2020  VIRGINIA      33191             ACCOMACK       51001
# 1    2020  VIRGINIA     114534            ALBEMARLE       51003
# 2    2020  VIRGINIA      14835            ALLEGHANY       51005
# 3    2020  VIRGINIA      13455               AMELIA       51007
# 4    2020  VIRGINIA      31589              AMHERST       51009
# ..    ...       ...        ...                  ...         ...
# 128  2020  VIRGINIA      98537         SUFFOLK CITY       51800
# 129  2020  VIRGINIA     455618  VIRGINIA BEACH CITY       51810
# 130  2020  VIRGINIA      22808      WAYNESBORO CITY       51820
# 131  2020  VIRGINIA      15920    WILLIAMSBURG CITY       51830
# 132  2020  VIRGINIA      27936      WINCHESTER CITY       51840
#
#     democrat_votes republican_votes total_votes
# 0             7578             9172       16962
# 1            42466            20804       64657
# 2             2243             5859        8203
# 3             2411             5390        7894
# 4             5672            11041       17005
# ..             ...              ...         ...
# 128          28676            20082       49642
# 129         117393           105087      227717
# 130           4961             5507       10717
# 131           4790             1963        6890
# 132           6610             5221       12113
#
# [133 rows x 8 columns]

# %% [markdown]
# ## US County Data

# %%
# Load county adjacency data and population data
us_county_voting_data = pd.read_csv('./project_voting/data/us_pres_data_by_county.csv')

us_county_voting_data = us_county_voting_data.drop(columns=['office', 'state_po'])
us_county_voting_data = us_county_voting_data.loc[~us_county_voting_data['county_name'].isin(['STATEWIDE WRITEIN', 'MAINE UOCAVA', 'FEDERAL PRECINCT'])]

#making county_name all uppercase and no spaces
us_county_voting_data['county_name'] = us_county_voting_data['county_name'].str.upper()
us_county_voting_data['county_name'] = us_county_voting_data['county_name'].str.replace(' ', '')

#converting county_fips to an int type
us_county_voting_data['county_fips'] = us_county_voting_data['county_fips'].astype(int)

#ensuring all data is in 2020
us_county_voting_data = us_county_voting_data.loc[us_county_voting_data['year'] == 2020]

#creating distinct dataset of US not Virginia and only Virginia
us_county_voting_data = us_county_voting_data.loc[us_county_voting_data['state'] != 'VIRGINIA']
va_county_voting_data = us_county_voting_data.loc[us_county_voting_data['state'] == 'VIRGINIA']
us_county_voting_data
# Out:
#        year    state county_name  county_fips          candidate        party  \
# 50524  2020  ALABAMA     AUTAUGA         1001  JOSEPH R BIDEN JR     DEMOCRAT
# 50525  2020  ALABAMA     AUTAUGA         1001              OTHER        OTHER
# 50526  2020  ALABAMA     AUTAUGA         1001     DONALD J TRUMP   REPUBLICAN
# 50527  2020  ALABAMA     BALDWIN         1003  JOSEPH R BIDEN JR     DEMOCRAT
# 50528  2020  ALABAMA     BALDWIN         1003              OTHER        OTHER
# ...     ...      ...         ...          ...                ...          ...
# 72612  2020  WYOMING    WASHAKIE        56043     DONALD J TRUMP   REPUBLICAN
# 72613  2020  WYOMING      WESTON        56045  JOSEPH R BIDEN JR     DEMOCRAT
# 72614  2020  WYOMING      WESTON        56045       JO JORGENSEN  LIBERTARIAN
# 72615  2020  WYOMING      WESTON        56045              OTHER        OTHER
# 72616  2020  WYOMING      WESTON        56045     DONALD J TRUMP   REPUBLICAN
#
#        candidatevotes  totalvotes   version   mode
# 50524            7503       27770  20220315  TOTAL
# 50525             429       27770  20220315  TOTAL
# 50526           19838       27770  20220315  TOTAL
# 50527           24578      109679  20220315  TOTAL
# 50528            1557      109679  20220315  TOTAL
# ...               ...         ...       ...    ...
# 72612            3245        4032  20220315  TOTAL
# 72613             360        3560  20220315  TOTAL
# 72614              46        3560  20220315  TOTAL
# 72615              47        3560  20220315  TOTAL
# 72616            3107        3560  20220315  TOTAL
#
# [20497 rows x 10 columns]

# %%
import csv

 # Load county adjacency data and population data
population_2000_to_2010 = pd.read_csv('project_voting/data/population_data_us_2000_to_2010.csv', quoting=csv.QUOTE_NONE)
population_2010_to_2020 = pd.read_csv('project_voting/data/population_data_us_2010_to_2020.csv', quoting=csv.QUOTE_NONE)

# %% [markdown]
# Basic cleaning of the county adjacency and population data to ensure consistency is done in the codes block below.

# %%
population_2000_to_2010['CTYNAME'] = population_2000_to_2010['CTYNAME'].str.upper()
population_2000_to_2010['CTYNAME'] = population_2000_to_2010['CTYNAME'].str.replace('COUNTY', '')
population_2000_to_2010['CTYNAME'] = population_2000_to_2010['CTYNAME'].str.replace(' ', '')
population_2000_to_2010['STNAME'] = population_2000_to_2010['STNAME'].str.upper()
population_2000_to_2010 = population_2000_to_2010.loc[population_2000_to_2010['COUNTY'] != 0]
population_2000_to_2010
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME     CTYNAME  \
# 1         50       3         6      1       1  ALABAMA     AUTAUGA
# 2         50       3         6      1       3  ALABAMA     BALDWIN
# 3         50       3         6      1       5  ALABAMA     BARBOUR
# 4         50       3         6      1       7  ALABAMA        BIBB
# 5         50       3         6      1       9  ALABAMA      BLOUNT
# ...      ...     ...       ...    ...     ...      ...         ...
# 3189      50       4         8     56      37  WYOMING  SWEETWATER
# 3190      50       4         8     56      39  WYOMING       TETON
# 3191      50       4         8     56      41  WYOMING       UINTA
# 3192      50       4         8     56      43  WYOMING    WASHAKIE
# 3193      50       4         8     56      45  WYOMING      WESTON
#
#       ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  POPESTIMATE2002  \
# 1                 43751            44021            44889            45909
# 2                140416           141342           144875           147957
# 3                 29042            29015            28863            28653
# 4                 19856            19913            21028            21199
# 5                 50982            51107            51845            52551
# ...                 ...              ...              ...              ...
# 3189              37620            37552            36899            37428
# 3190              18257            18381            18653            18837
# 3191              19745            19666            19413            19587
# 3192               8292             8252             8068             7988
# 3193               6643             6627             6487             6578
#
#       POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  POPESTIMATE2006  \
# 1               46800            48366            49676            51328
# 2              151509           156266           162183           168121
# 3               28594            28287            28027            27861
# 4               21399            21721            22042            22099
# 5               53457            54124            54624            55485
# ...               ...              ...              ...              ...
# 3189            37450            38026            38739            39749
# 3190            19066            19467            19632            20014
# 3191            19480            19470            19494            19709
# 3192             7976             7960             8022             7979
# 3193             6610             6646             6594             6717
#
#       POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  CENSUS2010POP  \
# 1               52405            53277            54135          54571
# 2              172404           175827           179406         182265
# 3               27757            27808            27657          27457
# 4               22438            22705            22941          22915
# 5               56240            57055            57341          57322
# ...               ...              ...              ...            ...
# 3189            41470            42358            44133          43806
# 3190            20472            20988            21232          21294
# 3191            20171            20613            21054          21118
# 3192             8169             8229             8423           8533
# 3193             7033             7133             7266           7208
#
#       POPESTIMATE2010
# 1               54632
# 2              183195
# 3               27411
# 4               22867
# 5               57338
# ...               ...
# 3189            43621
# 3190            21302
# 3191            21137
# 3192             8556
# 3193             7182
#
# [3143 rows x 20 columns]

# %%
population_2010_to_2020['CTYNAME'] = population_2010_to_2020['CTYNAME'].str.upper()
population_2010_to_2020['CTYNAME'] = population_2010_to_2020['CTYNAME'].str.replace('COUNTY', '')
population_2010_to_2020['CTYNAME'] = population_2010_to_2020['CTYNAME'].str.replace(' ', '')
population_2010_to_2020['STNAME'] = population_2010_to_2020['STNAME'].str.upper()
population_2010_to_2020 = population_2010_to_2020.loc[population_2010_to_2020['COUNTY'] != 0]
population_2010_to_2020
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME     CTYNAME  \
# 1         50       3         6      1       1  ALABAMA     AUTAUGA
# 2         50       3         6      1       3  ALABAMA     BALDWIN
# 3         50       3         6      1       5  ALABAMA     BARBOUR
# 4         50       3         6      1       7  ALABAMA        BIBB
# 5         50       3         6      1       9  ALABAMA      BLOUNT
# ...      ...     ...       ...    ...     ...      ...         ...
# 3189      50       4         8     56      37  WYOMING  SWEETWATER
# 3190      50       4         8     56      39  WYOMING       TETON
# 3191      50       4         8     56      41  WYOMING       UINTA
# 3192      50       4         8     56      43  WYOMING    WASHAKIE
# 3193      50       4         8     56      45  WYOMING      WESTON
#
#      CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  POPESTIMATE2012  \
# 1            54571              54582            54761  ...            54970
# 2           182265             182263           183121  ...           190203
# 3            27457              27454            27325  ...            27172
# 4            22915              22904            22858  ...            22657
# 5            57322              57322            57372  ...            57585
# ...            ...                ...              ...  ...              ...
# 3189         43806              43806            43580  ...            45032
# 3190         21294              21298            21298  ...            21643
# 3191         21118              21121            21090  ...            21008
# 3192          8533               8528             8531  ...             8410
# 3193          7208               7208             7198  ...             7075
#
#       POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# 1               54747            54922            54903            55302
# 2              194978           199306           203101           207787
# 3               26946            26768            26300            25828
# 4               22510            22541            22553            22590
# 5               57630            57536            57535            57487
# ...               ...              ...              ...              ...
# 3189            45189            44996            44780            44319
# 3190            22335            22801            23083            23255
# 3191            20969            20835            20777            20711
# 3192             8417             8277             8282             8180
# 3193             7132             7134             7202             7228
#
#       POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE042020  \
# 1               55448            55533            55769              56130
# 2              212737           218071           223565             227989
# 3               25169            24887            24657              24652
# 4               22532            22300            22313              22199
# 5               57801            57770            57840              57932
# ...               ...              ...              ...                ...
# 3189            43663            43188            42917              42717
# 3190            23383            23261            23385              23453
# 3191            20449            20299            20196              20169
# 3192             8013             7886             7824               7756
# 3193             6962             6895             6880               6752
#
#       POPESTIMATE2020
# 1               56145
# 2              229287
# 3               24589
# 4               22136
# 5               57879
# ...               ...
# 3189            42673
# 3190            23497
# 3191            20215
# 3192             7760
# 3193             6743
#
# [3143 rows x 21 columns]

# %%
print(us_county_voting_data['state'].unique())
# Out:
# ['ALABAMA' 'ALASKA' 'ARIZONA' 'ARKANSAS' 'CALIFORNIA' 'COLORADO'
#  'CONNECTICUT' 'DELAWARE' 'DISTRICT OF COLUMBIA' 'FLORIDA' 'GEORGIA'
#  'HAWAII' 'IDAHO' 'ILLINOIS' 'INDIANA' 'IOWA' 'KANSAS' 'KENTUCKY'
#  'LOUISIANA' 'MAINE' 'MICHIGAN' 'MINNESOTA' 'MISSISSIPPI' 'MISSOURI'
#  'NEVADA' 'NEW HAMPSHIRE' 'NEW JERSEY' 'NEW MEXICO' 'NEW YORK'
#  'NORTH CAROLINA' 'NORTH DAKOTA' 'OREGON' 'PENNSYLVANIA' 'RHODE ISLAND'
#  'SOUTH CAROLINA' 'TEXAS' 'VERMONT' 'WEST VIRGINIA' 'MARYLAND'
#  'MASSACHUSETTS' 'MONTANA' 'NEBRASKA' 'OHIO' 'OKLAHOMA' 'SOUTH DAKOTA'
#  'TENNESSEE' 'UTAH' 'WASHINGTON' 'WISCONSIN' 'WYOMING']

# %% [markdown]
# ## Combining Voting and Population Data

# %% [markdown]
# A function called reorganize_dataframe_us_data is defined below. It is quite similar to the reorganize_dataframe function previously, but it is made to handle the combined population data.

# %%
def reorganize_dataframe_us_data(df, pop_data_2000, pop_data_2010):
    states = df['state'].unique()
    # print(states)
    # print(pop_data_2010['STNAME'].unique())
    final_df = pd.DataFrame(columns=['year', 'state', 'population', 'county', 'county_fips', 'democrat_votes', 'republican_votes', 'total_votes'])
    for state in states:
        curr_df = df.loc[df['state'].str.replace(' ', '') == state.replace(' ', '')]
        curr_pop = pop_data_2010.loc[pop_data_2010['STNAME'].str.upper().replace(' ', '') == state.upper().replace(' ', '')]
        county_names = df.loc[df['state'].str.upper().replace(' ', '') == state.upper().replace(' ', ''), 'county_name'].unique()
        # index = len(county_names)
        # print(county_names)
        new_df = pd.DataFrame(columns=['year', 'state', 'population', 'county', 'county_fips', 'democrat_votes', 'republican_votes', 'total_votes'])
        index = 0
        # print(curr_pop.loc[curr_pop['CTYNAME'] == 'ST.CLAIR', 'POPESTIMATE2020'])
        for county in county_names:
            county = county.upper()
            county = county.replace(' ', '')

            dem_votes = calculate_votes(curr_df, 'county_name', 'party', 'candidatevotes', county, 'DEMOCRAT')
            rep_votes = calculate_votes(curr_df, 'county_name', 'party', 'candidatevotes', county, 'REPUBLICAN')
            county_fips = curr_df.loc[curr_df['county_name'].str.replace(" ", "") == county, 'county_fips'].unique()[0]
            total_votes = curr_df.loc[curr_df['county_name'].str.replace(" ", "") == county, 'totalvotes'].unique()[0]
            county_population = sum(curr_pop.loc[curr_pop['CTYNAME'] == county, 'POPESTIMATE2020'])
            # index = index + 1

            new_row = {'year': 2020, 'state': state, 'population': county_population, 'county': county, 'county_fips': county_fips, 'democrat_votes': dem_votes, 'republican_votes': rep_votes, 'total_votes': total_votes}
            new_df = pd.concat([new_df, pd.DataFrame([new_row])], ignore_index=True)
        frames = [final_df, new_df]
        final_df = pd.concat(frames, ignore_index=True)
        # print(new_df)
    return final_df

# %%
all_us_data = reorganize_dataframe_us_data(us_county_voting_data, population_2000_to_2010, population_2010_to_2020)

# %%
va_county_voting_data = reorganize_dataframe_us_data(va_county_voting_data, population_2000_to_2010, population_2010_to_2020)

# %%
# RESOURCES
# https://saturncloud.io/blog/how-to-remove-rows-with-specific-values-in-pandas-dataframe/

mask = all_us_data['state'].isin(['ALASKA', 'LOUISIANA'])
all_us_data = all_us_data[~mask]
all_us_data['state'].unique()
# Out:
# array(['ALABAMA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA', 'COLORADO',
#        'CONNECTICUT', 'DELAWARE', 'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO',
#        'ILLINOIS', 'INDIANA', 'IOWA', 'KANSAS', 'KENTUCKY', 'MAINE',
#        'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI', 'MISSOURI', 'NEVADA',
#        'OREGON', 'PENNSYLVANIA', 'TEXAS', 'VERMONT', 'MARYLAND',
#        'MASSACHUSETTS', 'MONTANA', 'NEBRASKA', 'OHIO', 'OKLAHOMA',
#        'TENNESSEE', 'UTAH', 'WASHINGTON', 'WISCONSIN', 'WYOMING'],
#       dtype=object)

# %%
all_us_data.loc[all_us_data['county'] == 'ST.LOUISCOUNTY', 'county'] = 'ST.LOUIS'
all_us_data.loc[all_us_data['county'] == 'ST.LOUIS', 'population'] = 994020
all_us_data = all_us_data[all_us_data.county != 'KANSASCITY']
all_us_data.loc[all_us_data['state'] == 'KANSAS']
all_us_data.loc[all_us_data['county'] == 'SAINTLOUIS', 'population'] = 198538
all_us_data.loc[all_us_data['county'] == "STMARY'S", 'population'] = 114687

# %%
va_data_2020.loc[va_data_2020['county'] == "CHARLES CITY", 'population'] = 6821
va_data_2020.loc[va_data_2020['county'] == "JAMES CITY", 'population'] = 77612

# %% [markdown]
# ## Writing the data to csv files

# %%
all_us_data.to_csv('training_data.csv', index=False)
va_data_2020.to_csv('testing_data.csv', index=False)
